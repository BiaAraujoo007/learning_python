# %% [markdown]
# <a href="https://colab.research.google.com/github/BiaAraujoo007/learning_python/blob/main/Teste01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
meu_set = {1, 2, 2, 3, 4, 3}
print(len(meu_set)
# Out:
# 4

# %%
meu_dict = {
    "nome": "Alice",
    "idade": 18,
    "peso": 54.3,
}
print(meu_dict["peso"])
meu_dict["nome"]
meu_dict.keys()
meu_dict.values()
meu_dict.items()
# Out:
# 54.3
# dict_items([('nome', 'Alice'), ('idade', 18), ('peso', 54.3)])
